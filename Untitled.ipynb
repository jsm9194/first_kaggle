# %%
import pandas as pd

# %%
df = pd.read_csv('./DATA/train.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr()
# Out:
#                         ID     PRICE  BEDROOMS  BATHROOMS    GARAGE  \
# ID                1.000000  0.002149  0.007004  -0.000146 -0.010428
# PRICE             0.002149  1.000000  0.256909   0.386485  0.124276
# BEDROOMS          0.007004  0.256909  1.000000   0.558640  0.180447
# BATHROOMS        -0.000146  0.386485  0.558640   1.000000  0.181213
# GARAGE           -0.010428  0.124276  0.180447   0.181213  1.000000
# LAND_AREA        -0.007281  0.046778  0.047265   0.028357  0.042186
# FLOOR_AREA        0.006915  0.539524  0.536185   0.556328  0.186341
# BUILD_YEAR        0.000651 -0.148771  0.234275   0.345848  0.045461
# CBD_DIST          0.000779 -0.357368  0.120185   0.028758  0.042033
# NEAREST_STN_DIST  0.003104 -0.099370  0.105443   0.033446  0.101591
# POSTCODE          0.003222 -0.162925  0.019795  -0.032696  0.019979
# LATITUDE         -0.011983  0.046722  0.023951   0.048622 -0.011987
# LONGITUDE        -0.006936 -0.183514 -0.011119  -0.094269  0.085201
# ...

# %%
df = df.drop(['ID','ADDRESS', 'POSTCODE','LATITUDE', 'LONGITUDE', 'NEAREST_SCH_RANK','DATE_SOLD' ], axis= 1)
df
# Out:
#                 SUBURB    PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  \
# 0            Ridgewood   520000         5          2     4.0        674
# 1            Landsdale   575000         5          4     2.0        540
# 2             Mindarie   760000         4          2     2.0        781
# 3       Mount Hawthorn  1230000         2          1     2.0        425
# 4      North Fremantle  2010000         3          2     2.0        546
# ...                ...      ...       ...        ...     ...        ...
# 18505          Hocking   475000         4          2     2.0        533
# 18506   Champion Lakes   485000         3          2     2.0        344
# 18507        Redcliffe   642000         3          1     1.0       1016
# 18508           Samson   491000         4          2     2.0        718
# 18509        Koondoola   490000         4          1     2.0       1030
#
#        FLOOR_AREA  BUILD_YEAR  CBD_DIST              NEAREST_STN  \
# ...

# %%
df.isnull().sum()
# Out:
# SUBURB                 0
# PRICE                  0
# BEDROOMS               0
# BATHROOMS              0
# GARAGE              1367
# LAND_AREA              0
# FLOOR_AREA             0
# BUILD_YEAR          1728
# CBD_DIST               0
# NEAREST_STN            0
# NEAREST_STN_DIST       0
# NEAREST_SCH            0
# NEAREST_SCH_DIST       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18510 entries, 0 to 18509
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            18510 non-null  object
#  1   PRICE             18510 non-null  int64
#  2   BEDROOMS          18510 non-null  int64
#  3   BATHROOMS         18510 non-null  int64
#  4   GARAGE            17143 non-null  float64
#  5   LAND_AREA         18510 non-null  int64
#  6   FLOOR_AREA        18510 non-null  int64
#  7   BUILD_YEAR        16782 non-null  float64
#  8   CBD_DIST          18510 non-null  int64
#  9   NEAREST_STN       18510 non-null  object
#  10  NEAREST_STN_DIST  18510 non-null  int64
#  11  NEAREST_SCH       18510 non-null  object
#  12  NEAREST_SCH_DIST  18510 non-null  float64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.8+ MB

# %%
df['GARAGE']
# Out:
# 0        4.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 18505    2.0
# 18506    2.0
# 18507    1.0
# 18508    2.0
# 18509    2.0
# Name: GARAGE, Length: 18510, dtype: float64

# %%
df['GARAGE'] = df['GARAGE'].fillna(df['GARAGE'].mean())

df['GARAGE'].isnull().sum()
df['GARAGE'].describe()
# Out:
# count    18510.000000
# mean         2.199790
# std          1.376632
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          2.000000
# max         99.000000
# Name: GARAGE, dtype: float64

# %%
df['BUILD_YEAR'].describe()
# Out:
# count    16782.000000
# mean      1989.805327
# std         21.003456
# min       1868.000000
# 25%       1979.000000
# 50%       1995.000000
# 75%       2005.000000
# max       2017.000000
# Name: BUILD_YEAR, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
build_year = df['BUILD_YEAR'].sort_values()
build_year.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns
sns.boxplot(df['BUILD_YEAR'])
plt.show()

# %%
df[df['BUILD_YEAR'].isnull()]
# Out:
#                 SUBURB    PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  \
# 17        Wattle Grove  1200000         4          3     4.0       1907
# 18         Churchlands   890000         3          2     2.0        922
# 19        Glen Forrest   615000         4          2     2.0       2004
# 22     East Cannington   490000         3          2     2.0        441
# 28            Parkwood   456420         3          1     1.0        703
# ...                ...      ...       ...        ...     ...        ...
# 18459          Yanchep   370000         4          2     2.0        643
# 18466       Swanbourne  1517000         4          2     1.0        809
# 18487  South Fremantle  1050000         5          2     1.0        470
# 18492        Hamersley   472000         3          1     1.0        918
# 18501     Shenton Park   817000         3          2     2.0        440
#
#        FLOOR_AREA  BUILD_YEAR  CBD_DIST           NEAREST_STN  \
# ...

# %%
df['BUILD_YEAR'].mean()
# Out:
# 1989.8053271362173

# %%
df = df.dropna(axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16782 entries, 0 to 18509
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            16782 non-null  object
#  1   PRICE             16782 non-null  int64
#  2   BEDROOMS          16782 non-null  int64
#  3   BATHROOMS         16782 non-null  int64
#  4   GARAGE            16782 non-null  float64
#  5   LAND_AREA         16782 non-null  int64
#  6   FLOOR_AREA        16782 non-null  int64
#  7   BUILD_YEAR        16782 non-null  float64
#  8   CBD_DIST          16782 non-null  int64
#  9   NEAREST_STN       16782 non-null  object
#  10  NEAREST_STN_DIST  16782 non-null  int64
#  11  NEAREST_SCH       16782 non-null  object
#  12  NEAREST_SCH_DIST  16782 non-null  float64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.8+ MB

# %%
df['SUBURB'].describe()
# Out:
# count       16782
# unique        317
# top       Bertram
# freq          127
# Name: SUBURB, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder.fit(df.SUBURB)
df.SUBURB = encoder.transform(df.SUBURB)
df.SUBURB
# Out:
# C:\project\AI_Source\venv\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 0        243
# 1        167
# 2        195
# 3        200
# 4        219
#         ...
# 18505    133
# 18506     64
# 18507    242
# 18508    251
# 18509    164
# Name: SUBURB, Length: 16782, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16782 entries, 0 to 18509
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            16782 non-null  int32
#  1   PRICE             16782 non-null  int64
#  2   BEDROOMS          16782 non-null  int64
#  3   BATHROOMS         16782 non-null  int64
#  4   GARAGE            16782 non-null  float64
#  5   LAND_AREA         16782 non-null  int64
#  6   FLOOR_AREA        16782 non-null  int64
#  7   BUILD_YEAR        16782 non-null  float64
#  8   CBD_DIST          16782 non-null  int64
#  9   NEAREST_STN       16782 non-null  object
#  10  NEAREST_STN_DIST  16782 non-null  int64
#  11  NEAREST_SCH       16782 non-null  object
#  12  NEAREST_SCH_DIST  16782 non-null  float64
# dtypes: float64(3), int32(1), int64(7), object(2)
# memory usage: 1.7+ MB

# %%
encoder = LabelEncoder()
encoder.fit(df.NEAREST_STN)
df.NEAREST_STN = encoder.transform(df.NEAREST_STN)
df.NEAREST_STN
# Out:
# 0         8
# 1        66
# 2        16
# 3        36
# 4        47
#          ..
# 18505    23
# 18506    33
# 18507     2
# 18508    46
# 18509    62
# Name: NEAREST_STN, Length: 16782, dtype: int32

# %%
encoder = LabelEncoder()
encoder.fit(df.NEAREST_SCH )
df.NEAREST_SCH  = encoder.transform(df.NEAREST_SCH)
df.NEAREST_SCH
# Out:
# 0         64
# 1         82
# 2         96
# 3          5
# 4         66
#         ...
# 18505    151
# 18506     69
# 18507     37
# 18508    124
# 18509     94
# Name: NEAREST_SCH, Length: 16782, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16782 entries, 0 to 18509
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            16782 non-null  int32
#  1   PRICE             16782 non-null  int64
#  2   BEDROOMS          16782 non-null  int64
#  3   BATHROOMS         16782 non-null  int64
#  4   GARAGE            16782 non-null  float64
#  5   LAND_AREA         16782 non-null  int64
#  6   FLOOR_AREA        16782 non-null  int64
#  7   BUILD_YEAR        16782 non-null  float64
#  8   CBD_DIST          16782 non-null  int64
#  9   NEAREST_STN       16782 non-null  int32
#  10  NEAREST_STN_DIST  16782 non-null  int64
#  11  NEAREST_SCH       16782 non-null  int32
#  12  NEAREST_SCH_DIST  16782 non-null  float64
# dtypes: float64(3), int32(3), int64(7)
# memory usage: 1.6 MB

# %%
df.SUBURB.unique()
# Out:
# array([243, 167, 195, 200, 219,  72, 234, 233, 178,  19, 263, 164, 124,
#        199, 205, 116, 147, 309,  65,  45, 136, 242, 177,  79, 170,  50,
#        277, 148, 143, 163,  94, 183, 245,   2,  48, 131,   9, 292,  34,
#          4,  41, 187, 190, 249, 151, 300,  62,  29, 228,  96, 125, 241,
#         39, 174, 203, 254, 290,   7, 123, 264, 122, 138, 269, 206, 286,
#        285, 175,  13, 261, 155, 239,  69, 275,  36,  21, 126, 189,  63,
#        111, 215, 276,  18, 255,  35, 210, 278, 244, 179,  64,  17, 246,
#        217, 213, 307,  57,  11, 176, 268, 270, 156, 308, 265, 208, 316,
#        296, 225, 188, 229, 139, 193, 251, 106,  98, 146, 150,  83, 237,
#        145,  74, 110,  43, 127, 230, 128,  66,  37, 113, 133, 204, 294,
#         99, 284, 105, 235,   8, 114, 211, 310,  81, 232, 315,  85, 115,
#        282,   0, 289, 102,  33,  16,  61,  53, 260, 247,  40, 240,  77,
#        259, 157,  90,  76, 258,  30, 311, 130, 144, 224, 120,   6, 291,
# ...

# %%
df.corr()
# Out:
#                     SUBURB     PRICE  BEDROOMS  BATHROOMS    GARAGE  \
# SUBURB            1.000000  0.036332  0.007179  -0.001176  0.000927
# PRICE             0.036332  1.000000  0.259703   0.389231  0.115083
# BEDROOMS          0.007179  0.259703  1.000000   0.561434  0.168588
# BATHROOMS        -0.001176  0.389231  0.561434   1.000000  0.170029
# GARAGE            0.000927  0.115083  0.168588   0.170029  1.000000
# LAND_AREA        -0.026568  0.043966  0.048565   0.030240  0.035748
# FLOOR_AREA        0.015904  0.544844  0.538512   0.563755  0.172976
# BUILD_YEAR       -0.047070 -0.148771  0.234275   0.345848  0.042995
# CBD_DIST          0.075023 -0.362101  0.117879   0.026370  0.038194
# NEAREST_STN       0.197919  0.006336 -0.041976  -0.072165 -0.026761
# NEAREST_STN_DIST  0.055077 -0.099753  0.106130   0.041449  0.093467
# NEAREST_SCH       0.116195 -0.010269 -0.015809  -0.029726 -0.023223
# NEAREST_SCH_DIST -0.012254 -0.021936  0.092802   0.058054  0.080274
#
# ...

# %%
x_data = df.drop(['PRICE'], axis= 1)
y_data = df['PRICE']

# %%
x_data.shape
# Out:
# (16782, 12)

# %%
y_data.shape
# Out:
# (16782,)

# %%
from sklearn import model_selection
from sklearn. metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model, datasets

x_train, x_test, y_train, y_test = model_selection.train_test_split(x_data, y_data, test_size = 0.33, random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11243 entries, 17797 to 17418
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBURB            11243 non-null  int32
#  1   BEDROOMS          11243 non-null  int64
#  2   BATHROOMS         11243 non-null  int64
#  3   GARAGE            11243 non-null  float64
#  4   LAND_AREA         11243 non-null  int64
#  5   FLOOR_AREA        11243 non-null  int64
#  6   BUILD_YEAR        11243 non-null  float64
#  7   CBD_DIST          11243 non-null  int64
#  8   NEAREST_STN       11243 non-null  int32
#  9   NEAREST_STN_DIST  11243 non-null  int64
#  10  NEAREST_SCH       11243 non-null  int32
#  11  NEAREST_SCH_DIST  11243 non-null  float64
# dtypes: float64(3), int32(3), int64(6)
# memory usage: 1010.1 KB

# %%
y_train
# Out:
# 17797    448000
# 17699    400000
# 18116    590000
# 11824    900000
# 18099    865000
#           ...
# 12451    252000
# 13195    479000
# 5937     642500
# 954      220000
# 17418    775000
# Name: PRICE, Length: 11243, dtype: int64

# %%
model = linear_model.LogisticRegression(solver = "liblinear")
model.fit(x_train, y_train)
# Out:
# C:\project\AI_Source\venv\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# LogisticRegression(solver='liblinear')

# %%
pred = model.predict(x_test)
score = accuracy_score(y_test, pred)
print('test score: ', score)
# Out:
# test score:  0.0124571222242282

# %%
df.corr()
# Out:
#                     SUBURB     PRICE  BEDROOMS  BATHROOMS    GARAGE  \
# SUBURB            1.000000  0.036332  0.007179  -0.001176  0.000927
# PRICE             0.036332  1.000000  0.259703   0.389231  0.115083
# BEDROOMS          0.007179  0.259703  1.000000   0.561434  0.168588
# BATHROOMS        -0.001176  0.389231  0.561434   1.000000  0.170029
# GARAGE            0.000927  0.115083  0.168588   0.170029  1.000000
# LAND_AREA        -0.026568  0.043966  0.048565   0.030240  0.035748
# FLOOR_AREA        0.015904  0.544844  0.538512   0.563755  0.172976
# BUILD_YEAR       -0.047070 -0.148771  0.234275   0.345848  0.042995
# CBD_DIST          0.075023 -0.362101  0.117879   0.026370  0.038194
# NEAREST_STN       0.197919  0.006336 -0.041976  -0.072165 -0.026761
# NEAREST_STN_DIST  0.055077 -0.099753  0.106130   0.041449  0.093467
# NEAREST_SCH       0.116195 -0.010269 -0.015809  -0.029726 -0.023223
# NEAREST_SCH_DIST -0.012254 -0.021936  0.092802   0.058054  0.080274
#
# ...

# %%
df
# Out:
#        SUBURB    PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  FLOOR_AREA  \
# 0         243   520000         5          2     4.0        674         266
# 1         167   575000         5          4     2.0        540         301
# 2         195   760000         4          2     2.0        781         220
# 3         200  1230000         2          1     2.0        425         185
# 4         219  2010000         3          2     2.0        546         186
# ...       ...      ...       ...        ...     ...        ...         ...
# 18505     133   475000         4          2     2.0        533         198
# 18506      64   485000         3          2     2.0        344         237
# 18507     242   642000         3          1     1.0       1016         110
# 18508     251   491000         4          2     2.0        718         176
# 18509     164   490000         4          1     2.0       1030         109
#
# ...

# %%
df = df.drop(["ID","ADDRESS","SUBURB", "LAND_AREA", "NEAREST_STN", "NEAREST_STN_DIST", "NEAREST_SCH_DIST", "GARAGE", "BUILD_YEAR", "DATE_SOLD", "POSTCODE", "LATITUDE", "NEAREST_SCH"], axis=1)
# Out:
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8436\2551678106.py in <module>
# ----> 1 df = df.drop(["ID","ADDRESS","SUBURB", "LAND_AREA", "NEAREST_STN", "NEAREST_STN_DIST", "NEAREST_SCH_DIST", "GARAGE", "BUILD_YEAR", "DATE_SOLD", "POSTCODE", "LATITUDE", "NEAREST_SCH"], axis=1)
#
# C:\project\AI_Source\venv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\project\AI_Source\venv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
df = df.drop['LONGITUDE']

# %%
df = df.drop(['LONGITUDE'], axis=1)

# %%
df.corr()

# %%
df.info()

# %%
df['NEAREST_SCH_RANK'] = df['NEAREST_SCH_RANK'].fillna(df['NEAREST_SCH_RANK'].max())

df['NEAREST_SCH_RANK'].isnull().sum()
df['NEAREST_SCH_RANK'].describe()

# %%
df['NEAREST_SCH_RANK'] = df.astype({'NEAREST_SCH_RANK':'int64'})

# %%
df.dtypes

# %%
df = df.astype(dtype = 'float64')
